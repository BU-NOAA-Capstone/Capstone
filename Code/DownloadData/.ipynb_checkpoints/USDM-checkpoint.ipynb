# %%
import requests
import re
import numpy as np
import pandas as pd
import os
import json

# %%
# refer https://droughtmonitor.unl.edu/WebServiceInfo.aspx#comp
Area = 'CountyStatistics'
Stat_type = 'GetDroughtSeverityStatisticsByAreaPercent'
BASE_URL = f'https://usdmdataservices.unl.edu/api/{Area}/{Stat_type}'
BASE_URL
# Out:
# 'https://usdmdataservices.unl.edu/api/CountyStatistics/GetDroughtSeverityStatisticsByAreaPercent'

# %%
# Definign dates (M/D/YYYY)
startdate = '1/1/2021'
enddate = '2/1/2021'

# %%
# Loading the FIPS codes
codes = pd.read_csv('NY_county_FIPS.csv')
codes.head()
# Out:
#                                             Counties
# 0   {"state":"NY","id":"36001","name":"Albany Cou...
# 1   {"state":"NY","id":"36003","name":"Allegany C...
# 2   {"state":"NY","id":"36005","name":"Bronx Coun...
# 3   {"state":"NY","id":"36007","name":"Broome Cou...
# 4   {"state":"NY","id":"36009","name":"Cattaraugu...

# %%
codeslist = []
for i in codes['Counties']:
    dic = json.loads(i)
    codeslist.append(dic['id'])

# %%
# Other parameters
master_req = []
for c in codeslist:
    params = {
    'aoi' : c, #FIPS code for county Tompkins
    'startdate' : startdate, # M/D/YYYY
    'enddate' : enddate,
    'statisticsType' : '1' # 1 for traditional or 2 for categorical.
    }
    req = requests.get(BASE_URL, params=params)
    c_data = req.json()
    master_req.append(c_data)

# %%
master_req[:3]
# Out:
# [[{'MapDate': '20210126',
#    'FIPS': '36001',
#    'County': 'Albany County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-26',
#    'ValidEnd': '2021-02-01',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210119',
#    'FIPS': '36001',
#    'County': 'Albany County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-19',
#    'ValidEnd': '2021-01-25',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210112',
#    'FIPS': '36001',
#    'County': 'Albany County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-12',
#    'ValidEnd': '2021-01-18',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210105',
#    'FIPS': '36001',
#    'County': 'Albany County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-05',
#    'ValidEnd': '2021-01-11',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20201229',
#    'FIPS': '36001',
#    'County': 'Albany County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2020-12-29',
#    'ValidEnd': '2021-01-04',
#    'StatisticFormatID': '1'}],
#  [{'MapDate': '20210126',
#    'FIPS': '36003',
#    'County': 'Allegany County',
#    'State': 'NY',
#    'None': '1.06',
#    'D0': '98.94',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-26',
#    'ValidEnd': '2021-02-01',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210119',
#    'FIPS': '36003',
#    'County': 'Allegany County',
#    'State': 'NY',
#    'None': '1.06',
#    'D0': '98.94',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-19',
#    'ValidEnd': '2021-01-25',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210112',
#    'FIPS': '36003',
#    'County': 'Allegany County',
#    'State': 'NY',
#    'None': '1.06',
#    'D0': '98.94',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-12',
#    'ValidEnd': '2021-01-18',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210105',
#    'FIPS': '36003',
#    'County': 'Allegany County',
#    'State': 'NY',
#    'None': '1.07',
#    'D0': '98.93',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-05',
#    'ValidEnd': '2021-01-11',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20201229',
#    'FIPS': '36003',
#    'County': 'Allegany County',
#    'State': 'NY',
#    'None': '1.07',
#    'D0': '98.93',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2020-12-29',
#    'ValidEnd': '2021-01-04',
#    'StatisticFormatID': '1'}],
#  [{'MapDate': '20210126',
#    'FIPS': '36005',
#    'County': 'Bronx County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-26',
#    'ValidEnd': '2021-02-01',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210119',
#    'FIPS': '36005',
#    'County': 'Bronx County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-19',
#    'ValidEnd': '2021-01-25',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210112',
#    'FIPS': '36005',
#    'County': 'Bronx County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-12',
#    'ValidEnd': '2021-01-18',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20210105',
#    'FIPS': '36005',
#    'County': 'Bronx County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2021-01-05',
#    'ValidEnd': '2021-01-11',
#    'StatisticFormatID': '1'},
#   {'MapDate': '20201229',
#    'FIPS': '36005',
#    'County': 'Bronx County',
#    'State': 'NY',
#    'None': '100.00',
#    'D0': '0.00',
#    'D1': '0.00',
#    'D2': '0.00',
#    'D3': '0.00',
#    'D4': '0.00',
#    'ValidStart': '2020-12-29',
#    'ValidEnd': '2021-01-04',
#    'StatisticFormatID': '1'}]]

# %%
# Saving the file
save_path = '../../../../../../../Google Drive/Shared drives/Capstone Project/Data/USDM/' \
+ Area + '_' + startdate.replace('/','') + '-' + enddate.replace('/','')
save_path
# Out:
# '../../../../../../../Google Drive/Shared drives/Capstone Project/Data/USDM/CountyStatistics_112021-212021'

# %%
os.makedirs(os.path.dirname(save_path), exist_ok=True)
with open(save_path, 'w') as f:
    json.dump(master_req, f)
