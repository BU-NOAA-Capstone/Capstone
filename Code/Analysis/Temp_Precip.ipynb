# %% [markdown]
# ## Data Preprocessing

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd/gdrive/Shareddrives/Capstone Project/Data/TempPrecip
# Out:
# /gdrive/Shareddrives/Capstone Project/Data/TempPrecip

# %%
import json
import pandas as pd
import numpy as np
import io
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Precip Data (avg precip value in NY counties)

# %%
path = "/gdrive/Shareddrives/Capstone Project/Data/TempPrecip/NY_Precip_2002-01-01_2020-12-31"
filename = 'NY_Precip_2002-01-01_2020-12-31'
with open(path, 'r' ) as f:
  precip = json.load(f)

# %%
res = [dict(zip(precip, i)) for i in zip(*precip.values())]
len(res)
type(res)
#[i.split('09001', 1)[0] for i in res]
dic = res.pop(0)
#type(dic)
l = dic['data']
#type(l)
l[0] #index of the dataframe
# Out:
# '2002-01-01'

# %%
# for loop getting the date as index
# list of days
datelist = []
for d in res:
  #print(d)
  l = d['data']
  #print(type(l))
  datelist.append(l[0])

datelist
#type(datelist)

# %%
# dict of county key and precip value
preciplist = []
for d in res:
  q = d['data']
  n = q[-1]
  preciplist.append(n)

# %%
precip = pd.DataFrame(preciplist,index=datelist)
precip

# %%
# Precip DataFrame in NY Counties 
precip= precip[['36001', 
'36003', 
'36005',
'36007',
'36009',
'36011',
'36013',
'36015',
'36017',
'36019',
'36021',
'36023',
'36025',
'36027',
'36029',
'36031',
'36033',
'36035',
'36037',
'36039',
'36041',
'36043',
'36045',
'36047',
'36049',
'36051',
'36053',
'36055',
'36057',
'36059',
'36061',
'36063',
'36065',
'36067',
'36069',
'36071',
'36073',
'36075',
'36077',
'36079',
'36081',
'36083',
'36085',
'36087',
'36089',
'36091',
'36093',
'36095',
'36097',
'36099',
'36101',
'36103',
'36105',
'36107',
'36109',
'36111',
'36113',
'36115',
'36117',
'36119','36121',
'36123']]

# %% [markdown]
# ## Temp Data (avg, max, and min temp value in NY counties)

# %%
# temp
path = "/gdrive/Shareddrives/Capstone Project/Data/TempPrecip/NY_Temp_2000-01-01_2020-12-31"
filename = 'NY_Temp_2000-01-01_2020-12-31'
with open(path, 'r' ) as f:
  temp = json.load(f)

# %%
res = [dict(zip(temp, i)) for i in zip(*temp.values())]
len(res)
type(res)
#[i.split('09001', 1)[0] for i in res]
dic = res.pop(0)
#type(dic)
l = dic['data']
#type(l)
l[0] #index of the dataframe
# Out:
# '2000-01-01'

# %%
# for loop getting the date as index
# list of days
datelist1 = []
for d in res:
  #print(d)
  l = d['data']
  #print(type(l))
  datelist1.append(l[0])

datelist1
#type(datelist)

# %%
# list of avg temp
temp_avg_list = []
for d in res:
  q = d['data']
  n = q[1]
  temp_avg_list.append(n)
temp_avg_list

# %%
# list of max temp
temp_max_list = []
for d in res:
  q = d['data']
  n = q[2]
  temp_max_list.append(n)
temp_max_list

# %%
# list of min temp
temp_min_list = []
for d in res:
  q = d['data']
  n = q[2]
  temp_min_list.append(n)
temp_min_list

# %%
#datafram_AVG
#date as index, county id as column, input as avg temp
df_avg = pd.DataFrame(temp_avg_list,index=datelist1)
#df_avg

df_avg.index = pd.to_datetime(df_avg.index,format='%Y-%m-%d')
df_avg

df_avg = df_avg[['36001', 
'36003', 
'36005',
'36007',
'36009',
'36011',
'36013',
'36015',
'36017',
'36019',
'36021',
'36023',
'36025',
'36027',
'36029',
'36031',
'36033',
'36035',
'36037',
'36039',
'36041',
'36043',
'36045',
'36047',
'36049',
'36051',
'36053',
'36055',
'36057',
'36059',
'36061',
'36063',
'36065',
'36067',
'36069',
'36071',
'36073',
'36075',
'36077',
'36079',
'36081',
'36083',
'36085',
'36087',
'36089',
'36091',
'36093',
'36095',
'36097',
'36099',
'36101',
'36103',
'36105',
'36107',
'36109',
'36111',
'36113',
'36115',
'36117',
'36119','36121',
'36123']]

df2 = df_avg.copy()
df2.index = pd.to_datetime(df_avg.index,format='%Y-%m-%d')
df2['date'] = pd.to_datetime(df2.index)
avg_T_w= df2.resample('7D',on='date').sum()
avg_T_w
# Out:
#                  36001       36003  ...       36121       36123
# date                                ...
# 2000-01-02  214.358986  240.529293  ...  239.018446  236.879473
# 2000-01-09  172.688065  171.331308  ...  173.176023  180.387046
# 2000-01-16   33.953849   56.800426  ...   60.637452   61.173379
# 2000-01-23   54.622031   42.559373  ...   57.532897   67.408399
# 2000-01-30   90.223173  112.124452  ...  124.961619  127.206189
# ...                ...         ...  ...         ...         ...
# 2020-11-29  274.040243  237.912085  ...  248.541332  261.742655
# 2020-12-06  210.119026  205.914865  ...  215.043327  222.215931
# 2020-12-13  174.520155  179.370697  ...  179.508266  186.876137
# 2020-12-20  218.251791  201.570242  ...  218.579601  218.853373
# 2020-12-27  133.744061  126.055655  ...  132.952320  142.801119
#
# [1096 rows x 62 columns]

# %%
#datafram_MAX
#date as index, county id as column, input as max temp
df_max = pd.DataFrame(temp_max_list,index=datelist1)
df_max.index = pd.to_datetime(df_avg.index,format='%Y-%m-%d')
df_max = df_max[['36001', 
'36003', 
'36005',
'36007',
'36009',
'36011',
'36013',
'36015',
'36017',
'36019',
'36021',
'36023',
'36025',
'36027',
'36029',
'36031',
'36033',
'36035',
'36037',
'36039',
'36041',
'36043',
'36045',
'36047',
'36049',
'36051',
'36053',
'36055',
'36057',
'36059',
'36061',
'36063',
'36065',
'36067',
'36069',
'36071',
'36073',
'36075',
'36077',
'36079',
'36081',
'36083',
'36085',
'36087',
'36089',
'36091',
'36093',
'36095',
'36097',
'36099',
'36101',
'36103',
'36105',
'36107',
'36109',
'36111',
'36113',
'36115',
'36117',
'36119','36121',
'36123']]
df_max

df3 = df_max.copy()
df3.index = pd.to_datetime(df_max.index,format='%Y-%m-%d')
df3['date'] = pd.to_datetime(df3.index)
max_T_w= df3.resample('7D',on='date').sum()
max_T_w
# Out:
#                  36001       36003  ...       36121       36123
# date                                ...
# 2000-01-02  294.070168  314.444689  ...  314.774101  309.631073
# 2000-01-09  224.398764  223.565958  ...  217.561445  223.424341
# 2000-01-16  110.218389  147.607790  ...  135.583619  131.969227
# 2000-01-23  120.387895  117.778980  ...  111.200248  118.239749
# 2000-01-30  164.716214  185.991940  ...  177.440350  180.312960
# ...                ...         ...  ...         ...         ...
# 2020-11-29  341.200226  285.186687  ...  283.191788  302.684525
# 2020-12-06  254.593100  255.892080  ...  258.070507  261.466370
# 2020-12-13  230.588211  224.015200  ...  219.947651  227.832830
# 2020-12-20  292.151814  246.366570  ...  261.569464  264.194815
# 2020-12-27  171.216805  161.867498  ...  167.265751  170.020300
#
# [1096 rows x 62 columns]

# %%
#datafram_MIn
#date as index, county id as column, input as min temp
df_min = pd.DataFrame(temp_min_list,index=datelist1)
df_min.index = pd.to_datetime(df_avg.index,format='%Y-%m-%d')

df_min = df_min[['36001', 
'36003', 
'36005',
'36007',
'36009',
'36011',
'36013',
'36015',
'36017',
'36019',
'36021',
'36023',
'36025',
'36027',
'36029',
'36031',
'36033',
'36035',
'36037',
'36039',
'36041',
'36043',
'36045',
'36047',
'36049',
'36051',
'36053',
'36055',
'36057',
'36059',
'36061',
'36063',
'36065',
'36067',
'36069',
'36071',
'36073',
'36075',
'36077',
'36079',
'36081',
'36083',
'36085',
'36087',
'36089',
'36091',
'36093',
'36095',
'36097',
'36099',
'36101',
'36103',
'36105',
'36107',
'36109',
'36111',
'36113',
'36115',
'36117',
'36119','36121',
'36123']]


df4 = df_min.copy()
df4.index = pd.to_datetime(df_min.index,format='%Y-%m-%d')
df4['date'] = pd.to_datetime(df4.index)
min_T_w= df4.resample('7D',on='date').sum()
min_T_w
# Out:
#                  36001       36003  ...       36121       36123
# date                                ...
# 2000-01-02  294.070168  314.444689  ...  314.774101  309.631073
# 2000-01-09  224.398764  223.565958  ...  217.561445  223.424341
# 2000-01-16  110.218389  147.607790  ...  135.583619  131.969227
# 2000-01-23  120.387895  117.778980  ...  111.200248  118.239749
# 2000-01-30  164.716214  185.991940  ...  177.440350  180.312960
# ...                ...         ...  ...         ...         ...
# 2020-11-29  341.200226  285.186687  ...  283.191788  302.684525
# 2020-12-06  254.593100  255.892080  ...  258.070507  261.466370
# 2020-12-13  230.588211  224.015200  ...  219.947651  227.832830
# 2020-12-20  292.151814  246.366570  ...  261.569464  264.194815
# 2020-12-27  171.216805  161.867498  ...  167.265751  170.020300
#
# [1096 rows x 62 columns]

# %% [markdown]
# ## Merge 3 Weekly Temp dataframes into 1 (df)

# %%
# merge Temp Avg, Min, Max
df_Temp = pd.merge(avg_T_w,min_T_w, on=avg_T_w.index)
#x is avg, y is max
#df_Temp = pd.merge(df_Temp, df_min, on=df_Temp.index)
df_Temp
#df_Temp.reset_index(drop=True)
#df_Temp
# Out:
#           key_0     36001_x     36003_x  ...     36119_y     36121_y     36123_y
# 0    2000-01-02  214.358986  240.529293  ...  335.633671  314.774101  309.631073
# 1    2000-01-09  172.688065  171.331308  ...  281.326571  217.561445  223.424341
# 2    2000-01-16   33.953849   56.800426  ...  160.176929  135.583619  131.969227
# 3    2000-01-23   54.622031   42.559373  ...  167.067739  111.200248  118.239749
# 4    2000-01-30   90.223173  112.124452  ...  217.922829  177.440350  180.312960
# ...         ...         ...         ...  ...         ...         ...         ...
# 1091 2020-11-29  274.040243  237.912085  ...  364.867302  283.191788  302.684525
# 1092 2020-12-06  210.119026  205.914865  ...  286.206953  258.070507  261.466370
# 1093 2020-12-13  174.520155  179.370697  ...  262.340004  219.947651  227.832830
# 1094 2020-12-20  218.251791  201.570242  ...  308.120592  261.569464  264.194815
# 1095 2020-12-27  133.744061  126.055655  ...  192.297096  167.265751  170.020300
#
# [1096 rows x 125 columns]

# %%
df_Temp = df_Temp.set_index('key_0')

# %%
df_Temp
df = pd.merge(df_Temp, min_T_w, on=min_T_w.index)
df
# Out:
#           key_0     36001_x     36003_x  ...       36119       36121       36123
# 0    2000-01-02  214.358986  240.529293  ...  335.633671  314.774101  309.631073
# 1    2000-01-09  172.688065  171.331308  ...  281.326571  217.561445  223.424341
# 2    2000-01-16   33.953849   56.800426  ...  160.176929  135.583619  131.969227
# 3    2000-01-23   54.622031   42.559373  ...  167.067739  111.200248  118.239749
# 4    2000-01-30   90.223173  112.124452  ...  217.922829  177.440350  180.312960
# ...         ...         ...         ...  ...         ...         ...         ...
# 1091 2020-11-29  274.040243  237.912085  ...  364.867302  283.191788  302.684525
# 1092 2020-12-06  210.119026  205.914865  ...  286.206953  258.070507  261.466370
# 1093 2020-12-13  174.520155  179.370697  ...  262.340004  219.947651  227.832830
# 1094 2020-12-20  218.251791  201.570242  ...  308.120592  261.569464  264.194815
# 1095 2020-12-27  133.744061  126.055655  ...  192.297096  167.265751  170.020300
#
# [1096 rows x 187 columns]

# %% [markdown]
# ## Precip Weekly Dataframe

# %%
df1 = precip.copy()
df1.index = pd.to_datetime(precip.index,format='%Y-%m-%d')
df1['date'] = pd.to_datetime(df1.index)
precip_w= df1.resample('7D',on='date').sum()
precip_w
# Out:
#                36001     36003     36005  ...     36119     36121     36123
# date                                      ...
# 2002-01-02  1.008552  0.282390  0.652124  ...  0.639644  0.164783  0.418347
# 2002-01-09  0.160985  0.078789  0.415525  ...  0.367365  0.284881  0.239835
# 2002-01-16  0.228838  0.156439  0.480564  ...  0.525534  0.372024  0.046524
# 2002-01-23  0.170018  0.077218  0.250914  ...  0.167673  0.206768  0.088929
# 2002-01-30  1.405798  2.112736  0.142040  ...  0.395117  2.932833  1.941235
# ...              ...       ...       ...  ...       ...       ...       ...
# 2020-12-02  0.302263  0.177401  1.335920  ...  1.265318  0.361299  0.239081
# 2020-12-09  0.136506  0.177674  0.256492  ...  0.181142  0.247368  0.092303
# 2020-12-16  2.064589  0.833504  0.902757  ...  0.987878  0.510814  0.737323
# 2020-12-23  1.895893  1.415446  1.147889  ...  1.628217  1.517673  1.500568
# 2020-12-30  0.110243  0.294980  0.146669  ...  0.184540  0.484940  0.050041
#
# [992 rows x 62 columns]
